# %%
import math
import numpy as np
import pandas as pd

from math import sin, cos, log, log10, exp, pi
from typing import Callable, Optional


pd.set_option("display.width", 200)

functions = [
    lambda x: x**2 + log(x), lambda x: x**2 - log10(x + 2), lambda x: x**2 + log(x) - 4,
    lambda x: (x - 1)**2 - 0.5*exp(x), lambda x: (x - 1)**2 - exp(-x), lambda x: x**3 - sin(x),
    lambda x: x - cos(x), lambda x: x**2 - cos(pi * x), lambda x: x**2 - sin(pi * x),
    lambda x: x**2 - cos(0.5 * pi * x), lambda x: x - 2*cos(0.5 * pi * x),
    lambda x: x - sin(pi * x), lambda x: 2*x - cos(x), lambda x: x**2 + log(x + 5),
    lambda x: 0.5 * x**2 + cos(2 * x), lambda x: x**2 - 0.5*exp(-x),
    lambda x: x**2 + log10(x), lambda x: x - log10(x + 2), lambda x: x**2 - log10(0.5 * x),
    lambda x: x**3 - cos(2 * x), lambda x: x**2 + cos(pi * x / 2), lambda x: x/2 - cos(x / 2)
]

values = [
    [0.52, 0.42, 0.87, 0.67],
    [0.53, 0.52, 0.97, 0.73],
    [1.52, 1.52, 1.97, 1.77],
    [0.13, 0.12, 0.57, 0.33],
    [1.07, 1.02, 1.47, 1.27],
    [0.92, 0.62, 1.07, 0.83],
    [0.37, 0.12, 0.57, 0.37],
    [0.77, 0.52, 0.97, 0.73],
    [0.92, 0.53, 0.98, 0.77],
    [0.37, 0.12, 0.58, 0.33],
    [0.53, 0.43, 0.86, 0.67],
    [0.64, 0.42, 0.87, 0.63],
    [0.71, 0.43, 0.87, 0.67],
    [0.88, 0.63, 1.08, 0.83],
    [0.44, 0.13, 0.58, 0.37],
    [0.73, 0.52, 0.97, 0.73],
    [0.84, 0.62, 1.07, 0.83],
    [0.37, 0.12, 0.58, 0.33],
    [0.53, 0.43, 0.86, 0.67],
    [0.77, 0.52, 0.97, 0.73],
    [0.92, 0.53, 0.98, 0.77],
    [0.37, 0.12, 0.58, 0.33],
    [0.13, 0.12, 0.57, 0.33],
    [0.64, 0.42, 0.87, 0.63],
]

intervals = [
    [0.4, 0.9], [0.5, 1.0], [1.5, 2.0], [0.1, 0.6], [1.0, 1.5], [0.6, 1.1],
    [0.1, 0.6], [0.5, 1.0], [0.5, 1.0], [0.1, 0.6], [0.4, 0.9], [0.4, 0.9],
    [0.4, 0.9], [0.6, 1.1], [0.1, 0.6], [0.5, 1.0], [0.6, 1.1], [0.1, 0.6],
    [0.4, 0.9], [0.5, 1.0], [0.5, 1.0], [0.1, 0.6], [0.1, 0.6], [0.4, 0.9]
]

abs_error = lambda x, y: abs(x - y) if x else "inf"


def compute_divided_differences_table(grid_nodes: list[int | float],
                                      grid_values: list[int | float]) -> list[float]:
    """
    Вычисляет таблицу разделенных разностей и возвращает разделенные разности.

    Args:
        grid_nodes (list[int | float]): Узловые точки (x_i).
        grid_values (list[int | float]): Значения функции в узловых точках (f(x_i)).

    Returns:
        list[float]: Список разделенных разностей.
    """
    n = len(grid_nodes)
    if n == 0:
        return []
    if n != len(grid_values):
        raise ValueError("grid_nodes и grid_values должны быть одной длины.")

    table = np.zeros((n, n))
    table[:, 0] = grid_values 

    for j in range(1, n): 
        for i in range(n - j):
            numerator = table[i+1, j-1] - table[i, j-1]
            denominator = grid_nodes[i+j] - grid_nodes[i]
            table[i, j] = numerator / denominator

    return table[0, :].tolist()


def interpolate(function: Callable[[int | float], float],
                x: int | float, a: int = 0, b: int = 0, 
                count: int = 10,
                grid: Optional[list[int | float]] = None,
                is_Lagrange: bool = True) -> Optional[float]:
    """
    Возвращает приближенное значение заданной функции в точке `x` при помощи интерпалиционного многочлена Лагранжа/Ньютона с равномерной сеткой.
    
    Args:
        function (Callable[[int | float], float]): функция, которую необходимо интерполировать.
        x (int | float): точка в которой нужно вычислить значение функции.
        a (int): значение первого узла (default 0).
        b (int): значение последнего узла (defautl 0).
        grid (Optional[list[int | float]]): если None, то сетка создается с равномерным шагом от `a` до `b` (и количество узлов равно count + 1) (default None).
        count (int): кол-во узлов сетки + 1 (default 10). 
        is_Lagrange (bool): True - если используется полином Лагранжа, иначе Ньютона (default True).
    
    Returns:
        float: вычесленной значение в точке `x`. 
        None: если нельзя вычислить значение функции в узле.
    """
    if grid is None:
        step = (b - a)/count
        grid = [a + i*step for i in range(count + 1)]
    else:
        grid = list(set(grid))
        count = len(grid) - 1
        
    y_values = []
    for node in grid:
        try:
            y_values.append(function(node))
        except (ValueError, TypeError, ZeroDivisionError) as e:
            print(f"Невозможно вычислить значение функции в узле `{node}`. Ошибка: {e}")
            return None
    
    if is_Lagrange:
        y_interpolate = 0
        
        for i in range(count + 1):
            prod = 1
            
            for j in range(count + 1):
                if i == j: continue
                prod *= (x - grid[j])/(grid[i] - grid[j])
            
            y_interpolate += prod * y_values[i]
    else:
        coeffs = compute_divided_differences_table(grid, y_values)
        y_interpolate, prod = 0, 1.0
        
        for i in range(count + 1):
            y_interpolate += coeffs[i] * prod
            prod *= (x - grid[i])         
        
    return y_interpolate
        

def get_k_nearest_nodes(grid: list[int | float], 
                        x: int | float, k: int = 1) -> list[int | float]:
    """
    Возвращает `k` ближайщих к `x` узлов в заданной сетке.
    
    Args:
        grid (list[int | float]): сетка узлов.
        x (int | float): значение по отнощению к которому будут искаться ближайщие узлы.
        k (int): количество ближайщих узлов (default 1).
    
    Returns:
        list[int | float]: ближайщие к `x` узлы сетки `grid`.
    """
    k = max(1, k)
    if k > len(grid): 
        k = len(grid) - 1
        
    return sorted(grid, key=lambda y: abs(x - y))[:k]
    
        
def get_interpolation_error_bounds(function: Callable[[int | float], float], 
                                   derivative_function: Callable[[int | float], float],
                                   min_derivative: Callable[[int | float], float], max_derivative: Callable[[int | float], float],
                                   grid: list[int | float], 
                                   x: int | float,
                                   n: int = 1) -> tuple[float]:
    """
    Возвращает нижнюю и верхнюю границы ошибки интерполирования и приближенное значение заданной функции в точке `x`.
    
    Args: 
        function (Callable[[int | float], float]): функция для которой необходимо вычислить интервал.
        derivative_function (Callable[[int | float], float]): производная n + 1 порядка исходной функции.
        min_derivative Callable[[int | float], float]: функция, которая определяет точку в которой производная имеет наименьшее значение.
        max_derivative Callable[[int | float], float]: функция, которая определяет точку в которой производная имеет наибольшее значение.
        grid (list[int | float]): сетка интерполяции.
        x (int | float): точка в которой необходимо вычислить интервал.
        n (int): порядок интерполирующего полинома (default 1).
    
    Returns:
        tuple[float]: граница интервала ошибки интерполяции и приближенное значение заданной функции в точке `x`, посчитаное по Лагранжу и Ньютону.
    """
    nearest_nodes = get_k_nearest_nodes(grid, x, k=n+1)
    derivative_min, derivative_max = derivative_function(min_derivative(nearest_nodes)), derivative_function(max_derivative(nearest_nodes))
    
    factorial = math.factorial(n + 1)
    prod = 1 / factorial
    for value in nearest_nodes:
        prod *= (x - value)
        
    derivative_min, derivative_max = sorted([derivative_min * prod, derivative_max * prod])
    return derivative_min, derivative_max, interpolate(function, x, grid=nearest_nodes), interpolate(function, x, grid=nearest_nodes, is_Lagrange=False)


def test_uniform_grid() -> None:
    """Тестирование интерполяции Лагранжа/ Ньютона с равномерной сеткой."""
    for ind, (function, interval, data) in enumerate(zip(functions, intervals, values)):
        print(f"Test: {ind + 1}")
        for x in data:
            print(f"Абсолютная ошибка Лагранжа в точке {x}:", abs_error(interpolate(function, x, *interval), function(x)))
            print(f"Абсолютная ошибка Ньютона в точке {x}:", abs_error(interpolate(function, x, *interval, is_Lagrange=False), function(x)))
            print("---")
        print()
        

def test_non_uniform_grid() -> None:
    """Тестирование интерполяции Лагранжа/ Ньютона с неравномерной сеткой."""
    grid = [0, 0.005, 0.0123, 0.051, 0,545, 0.675, 0.782, 0.895, 0.931, 1.012, 1.213, 1.324, 1.451, 1.567, 1.892, 2.123]
    
    for ind, (function, data) in enumerate(zip(functions, values)):
        print(f"Test: {ind + 1}")
        for x in data:
            print(f"Абсолютная ошибка Лагранжа в точке {x}:", abs_error(interpolate(function, x, grid=grid), function(x)))
            print(f"Абсолютная ошибка Ньютона в точке {x}:", abs_error(interpolate(function, x, grid=grid, is_Lagrange=False), function(x)))
            print("---")
        print()


def test_interpolation_evalution() -> None:
    """Тестирование ошиьки интерполяции Лагранжа/ Ньютона."""
    low_bound, high_bound = [], []
    interpolate_error_lagrange = []
    interpolate_error_newton = []
    
    data = values[3]
    degrees = []
    interval = intervals[3]
    function = functions[3]
    min_max_fun = [lambda x: max(x), lambda x: min(x)]
    
    for n, derivative_function, (a, b) in zip([1, 2], [lambda x: 2 - 0.5 * exp(x), lambda x: - 0.5 * exp(x)], [min_max_fun, min_max_fun]):
        for x in data:
            h = (interval[1] - interval[0]) / 11
            grid = [interval[0] + i * h for i in range(12)]
            low, high, lagrange, newton = get_interpolation_error_bounds(function, derivative_function, a, b, grid, x, n)
            
            low_bound.append(low)
            high_bound.append(high)
            degrees.append(n)
            interpolate_error_lagrange.append(function(x) - lagrange)
            interpolate_error_newton.append(function(x) - newton)
    
    result = pd.DataFrame({"x": data * 2, 
                           "Степень полинома": degrees, 
                           "Нижняя граница": low_bound,
                           "Ошибка интерполяции Лагранжа": interpolate_error_lagrange,
                           "Ошибка интерполяции Ньютона": interpolate_error_newton,
                           "Верхняя граница": high_bound})
    print(result)
        

if __name__ == "__main__":
    test_uniform_grid()
    test_non_uniform_grid()
    test_interpolation_evalution()
# Out:
# Test: 1
# Абсолютная ошибка Лагранжа в точке 0.52: 1.296876883660758e-09
# Абсолютная ошибка Ньютона в точке 0.52: 1.2968768281496068e-09
# ---
# Абсолютная ошибка Лагранжа в точке 0.42: 3.859756403379322e-08
# Абсолютная ошибка Ньютона в точке 0.42: 3.859756370072631e-08
# ---
# Абсолютная ошибка Лагранжа в точке 0.87: 1.2597962451010858e-08
# Абсолютная ошибка Ньютона в точке 0.87: 1.2597962339988555e-08
# ---
# Абсолютная ошибка Лагранжа в точке 0.67: 2.9586439548312526e-10
# Абсолютная ошибка Ньютона в точке 0.67: 2.958644787498521e-10
# ---
#
# Test: 2
# Абсолютная ошибка Лагранжа в точке 0.53: 1.2073675392798577e-15
# Абсолютная ошибка Ньютона в точке 0.53: 1.0824674490095276e-15
# ---
# Абсолютная ошибка Лагранжа в точке 0.52: 1.0824674490095276e-15
# Абсолютная ошибка Ньютона в точке 0.52: 1.5265566588595902e-15
# ---
# Абсолютная ошибка Лагранжа в точке 0.97: 1.5543122344752192e-15
# Абсолютная ошибка Ньютона в точке 0.97: 7.216449660063518e-16
# ---
# Абсолютная ошибка Лагранжа в точке 0.73: 1.3877787807814457e-17
# Абсолютная ошибка Ньютона в точке 0.73: 5.551115123125783e-17
# ---
#
# Test: 3
# Абсолютная ошибка Лагранжа в точке 1.52: 4.269917752708352e-13
# Абсолютная ошибка Ньютона в точке 1.52: 4.269917752708352e-13
# ---
# Абсолютная ошибка Лагранжа в точке 1.52: 4.269917752708352e-13
# Абсолютная ошибка Ньютона в точке 1.52: 4.269917752708352e-13
# ---
# Абсолютная ошибка Лагранжа в точке 1.97: 2.1294077612310502e-13
# Абсолютная ошибка Ньютона в точке 1.97: 2.1271873151818e-13
# ---
# Абсолютная ошибка Лагранжа в точке 1.77: 4.052314039881821e-15
# Абсолютная ошибка Ньютона в точке 1.77: 4.218847493575595e-15
# ---
#
# Test: 4
# Абсолютная ошибка Лагранжа в точке 0.13: 5.273559366969494e-16
# Абсолютная ошибка Ньютона в точке 0.13: 8.326672684688674e-17
# ---
# Абсолютная ошибка Лагранжа в точке 0.12: 1.3877787807814457e-16
# Абсолютная ошибка Ньютона в точке 0.12: 3.0531133177191805e-16
# ---
# Абсолютная ошибка Лагранжа в точке 0.57: 1.1102230246251565e-16
# Абсолютная ошибка Ньютона в точке 0.57: 2.220446049250313e-16
# ---
# Абсолютная ошибка Лагранжа в точке 0.33: 8.326672684688674e-17
# Абсолютная ошибка Ньютона в точке 0.33: 1.6653345369377348e-16
# ---
#
# Test: 5
# Абсолютная ошибка Лагранжа в точке 1.07: 0.0
# Абсолютная ошибка Ньютона в точке 1.07: 5.551115123125783e-17
# ---
# Абсолютная ошибка Лагранжа в точке 1.02: 5.551115123125783e-17
# Абсолютная ошибка Ньютона в точке 1.02: 5.551115123125783e-17
# ---
# Абсолютная ошибка Лагранжа в точке 1.47: 5.48172618408671e-16
# Абсолютная ошибка Ньютона в точке 1.47: 8.673617379884035e-18
# ---
# Абсолютная ошибка Лагранжа в точке 1.27: 2.7755575615628914e-17
# Абсолютная ошибка Ньютона в точке 1.27: 2.7755575615628914e-17
# ---
#
# Test: 6
# Абсолютная ошибка Лагранжа в точке 0.92: 7.979727989493313e-17
# Абсолютная ошибка Ньютона в точке 0.92: 9.020562075079397e-17
# ---
# Абсолютная ошибка Лагранжа в точке 0.62: 8.881784197001252e-16
# Абсолютная ошибка Ньютона в точке 0.62: 5.551115123125783e-17
# ---
# Абсолютная ошибка Лагранжа в точке 1.07: 5.551115123125783e-17
# Абсолютная ошибка Ньютона в точке 1.07: 1.6653345369377348e-16
# ---
# Абсолютная ошибка Лагранжа в точке 0.83: 5.551115123125783e-17
# Абсолютная ошибка Ньютона в точке 0.83: 5.551115123125783e-17
# ---
#
# Test: 7
# Абсолютная ошибка Лагранжа в точке 0.37: 0.0
# Абсолютная ошибка Ньютона в точке 0.37: 2.220446049250313e-16
# ---
# Абсолютная ошибка Лагранжа в точке 0.12: 2.220446049250313e-15
# Абсолютная ошибка Ньютона в точке 0.12: 6.661338147750939e-16
# ---
# Абсолютная ошибка Лагранжа в точке 0.57: 4.996003610813204e-16
# Абсолютная ошибка Ньютона в точке 0.57: 3.885780586188048e-16
# ---
# Абсолютная ошибка Лагранжа в точке 0.37: 0.0
# Абсолютная ошибка Ньютона в точке 0.37: 2.220446049250313e-16
# ---
#
# Test: 8
# Абсолютная ошибка Лагранжа в точке 0.77: 1.1235457009206584e-13
# Абсолютная ошибка Ньютона в точке 0.77: 1.1235457009206584e-13
# ---
# Абсолютная ошибка Лагранжа в точке 0.52: 1.0217215962171622e-11
# Абсолютная ошибка Ньютона в точке 0.52: 1.0221601343118891e-11
# ---
# Абсолютная ошибка Лагранжа в точке 0.97: 5.7771565309394646e-12
# Абсолютная ошибка Ньютона в точке 0.97: 5.773603817260664e-12
# ---
# Абсолютная ошибка Лагранжа в точке 0.73: 1.141309269314661e-13
# Абсолютная ошибка Ньютона в точке 0.73: 1.1435297153639112e-13
# ---
#
# Test: 9
# Абсолютная ошибка Лагранжа в точке 0.92: 1.0905720770892913e-12
# Абсолютная ошибка Ньютона в точке 0.92: 1.0906830993917538e-12
# ---
# Абсолютная ошибка Лагранжа в точке 0.53: 5.773159728050814e-12
# Абсолютная ошибка Ньютона в точке 0.53: 5.7734927949582016e-12
# ---
# Абсолютная ошибка Лагранжа в точке 0.98: 1.0220158053186879e-11
# Абсолютная ошибка Ньютона в точке 0.98: 1.0220269075489341e-11
# ---
# Абсолютная ошибка Лагранжа в точке 0.77: 1.139366379021567e-13
# Абсолютная ошибка Ньютона в точке 0.77: 1.139505156899645e-13
# ---
#
# Test: 10
# Абсолютная ошибка Лагранжа в точке 0.37: 2.220446049250313e-16
# Абсолютная ошибка Ньютона в точке 0.37: 2.220446049250313e-16
# ---
# Абсолютная ошибка Лагранжа в точке 0.12: 5.440092820663267e-15
# Абсолютная ошибка Ньютона в точке 0.12: 3.552713678800501e-15
# ---
# Абсолютная ошибка Лагранжа в точке 0.58: 5.2735593669694936e-15
# Абсолютная ошибка Ньютона в точке 0.58: 3.552713678800501e-15
# ---
# Абсолютная ошибка Лагранжа в точке 0.33: 1.1102230246251565e-16
# Абсолютная ошибка Ньютона в точке 0.33: 3.3306690738754696e-16
# ---
#
# Test: 11
# Абсолютная ошибка Лагранжа в точке 0.53: 6.661338147750939e-16
# Абсолютная ошибка Ньютона в точке 0.53: 5.551115123125783e-16
# ---
# Абсолютная ошибка Лагранжа в точке 0.43: 9.325873406851315e-15
# Абсолютная ошибка Ньютона в точке 0.43: 7.549516567451064e-15
# ---
# Абсолютная ошибка Лагранжа в точке 0.86: 2.7200464103316335e-15
# Абсолютная ошибка Ньютона в точке 0.86: 2.3869795029440866e-15
# ---
# Абсолютная ошибка Лагранжа в точке 0.67: 2.7755575615628914e-16
# Абсолютная ошибка Ньютона в точке 0.67: 2.220446049250313e-16
# ---
#
# Test: 12
# Абсолютная ошибка Лагранжа в точке 0.64: 4.3576253716537394e-14
# Абсолютная ошибка Ньютона в точке 0.64: 4.363176486776865e-14
# ---
# Абсолютная ошибка Лагранжа в точке 0.42: 5.457079232940032e-12
# Абсолютная ошибка Ньютона в точке 0.42: 5.457301277544957e-12
# ---
# Абсолютная ошибка Лагранжа в точке 0.87: 4.3778869418531485e-12
# Абсолютная ошибка Ньютона в точке 0.87: 4.378053475306842e-12
# ---
# Абсолютная ошибка Лагранжа в точке 0.63: 7.188694084447889e-14
# Абсолютная ошибка Ньютона в точке 0.63: 7.205347429817266e-14
# ---
#
# Test: 13
# Абсолютная ошибка Лагранжа в точке 0.71: 0.0
# Абсолютная ошибка Ньютона в точке 0.71: 0.0
# ---
# Абсолютная ошибка Лагранжа в точке 0.43: 1.1171619185290638e-15
# Абсолютная ошибка Ньютона в точке 0.43: 9.020562075079397e-17
# ---
# Абсолютная ошибка Лагранжа в точке 0.87: 4.440892098500626e-16
# Абсолютная ошибка Ньютона в точке 0.87: 2.220446049250313e-16
# ---
# Абсолютная ошибка Лагранжа в точке 0.67: 0.0
# Абсолютная ошибка Ньютона в точке 0.67: 1.1102230246251565e-16
# ---
#
# Test: 14
# Абсолютная ошибка Лагранжа в точке 0.88: 0.0
# Абсолютная ошибка Ньютона в точке 0.88: 4.440892098500626e-16
# ---
# Абсолютная ошибка Лагранжа в точке 0.63: 1.7763568394002505e-15
# Абсолютная ошибка Ньютона в точке 0.63: 2.220446049250313e-15
# ---
# Абсолютная ошибка Лагранжа в точке 1.08: 8.881784197001252e-15
# Абсолютная ошибка Ньютона в точке 1.08: 3.552713678800501e-15
# ---
# Абсолютная ошибка Лагранжа в точке 0.83: 4.440892098500626e-16
# Абсолютная ошибка Ньютона в точке 0.83: 4.440892098500626e-16
# ---
#
# Test: 15
# Абсолютная ошибка Лагранжа в точке 0.44: 8.881784197001252e-16
# Абсолютная ошибка Ньютона в точке 0.44: 8.881784197001252e-16
# ---
# Абсолютная ошибка Лагранжа в точке 0.13: 3.552713678800501e-14
# Абсолютная ошибка Ньютона в точке 0.13: 3.708144902248023e-14
# ---
# Абсолютная ошибка Лагранжа в точке 0.58: 6.672440377997191e-14
# Абсолютная ошибка Ньютона в точке 0.58: 6.517009154549669e-14
# ---
# Абсолютная ошибка Лагранжа в точке 0.37: 7.771561172376096e-16
# Абсолютная ошибка Ньютона в точке 0.37: 6.661338147750939e-16
# ---
#
# Test: 16
# Абсолютная ошибка Лагранжа в точке 0.73: 1.1102230246251565e-16
# Абсолютная ошибка Ньютона в точке 0.73: 1.1102230246251565e-16
# ---
# Абсолютная ошибка Лагранжа в точке 0.52: 1.1171619185290638e-15
# Абсолютная ошибка Ньютона в точке 0.52: 4.85722573273506e-17
# ---
# Абсолютная ошибка Лагранжа в точке 0.97: 1.3322676295501878e-15
# Абсолютная ошибка Ньютона в точке 0.97: 0.0
# ---
# Абсолютная ошибка Лагранжа в точке 0.73: 1.1102230246251565e-16
# Абсолютная ошибка Ньютона в точке 0.73: 1.1102230246251565e-16
# ---
#
# Test: 17
# Абсолютная ошибка Лагранжа в точке 0.84: 3.730571407345451e-12
# Абсолютная ошибка Ньютона в точке 0.84: 3.7309044742528386e-12
# ---
# Абсолютная ошибка Лагранжа в точке 0.62: 6.943672026249459e-10
# Абсолютная ошибка Ньютона в точке 0.62: 6.943679242699119e-10
# ---
# Абсолютная ошибка Лагранжа в точке 1.07: 2.6770430316958027e-10
# Абсолютная ошибка Ньютона в точке 1.07: 2.6770319294655565e-10
# ---
# Абсолютная ошибка Лагранжа в точке 0.83: 6.237566019251517e-12
# Абсолютная ошибка Ньютона в точке 0.83: 6.237343974646592e-12
# ---
#
# Test: 18
# Абсолютная ошибка Лагранжа в точке 0.37: 8.326672684688674e-17
# Абсолютная ошибка Ньютона в точке 0.37: 4.336808689942018e-17
# ---
# Абсолютная ошибка Лагранжа в точке 0.12: 7.13318293321663e-15
# Абсолютная ошибка Ньютона в точке 0.12: 6.716849298982197e-15
# ---
# Абсолютная ошибка Лагранжа в точке 0.58: 6.078471059822732e-15
# Абсолютная ошибка Ньютона в точке 0.58: 5.800915303666443e-15
# ---
# Абсолютная ошибка Лагранжа в точке 0.33: 1.0408340855860843e-16
# Абсолютная ошибка Ньютона в точке 0.33: 1.1796119636642288e-16
# ---
#
# Test: 19
# Абсолютная ошибка Лагранжа в точке 0.53: 4.553234456139421e-10
# Абсолютная ошибка Ньютона в точке 0.53: 4.553237786808495e-10
# ---
# Абсолютная ошибка Лагранжа в точке 0.43: 1.0429487939944693e-08
# Абсолютная ошибка Ньютона в точке 0.43: 1.0429490715502254e-08
# ---
# Абсолютная ошибка Лагранжа в точке 0.86: 2.2570654234499443e-09
# Абсолютная ошибка Ньютона в точке 0.86: 2.2570654234499443e-09
# ---
# Абсолютная ошибка Лагранжа в точке 0.67: 1.2849232788880727e-10
# Абсолютная ошибка Ньютона в точке 0.67: 1.2849232788880727e-10
# ---
#
# Test: 20
# Абсолютная ошибка Лагранжа в точке 0.77: 1.0547118733938987e-15
# Абсолютная ошибка Ньютона в точке 0.77: 1.1657341758564144e-15
# ---
# Абсолютная ошибка Лагранжа в точке 0.52: 9.298117831235686e-14
# Абсолютная ошибка Ньютона в точке 0.52: 9.470202400052585e-14
# ---
# Абсолютная ошибка Лагранжа в точке 0.97: 6.306066779870889e-14
# Абсолютная ошибка Ньютона в точке 0.97: 6.17284001691587e-14
# ---
# Абсолютная ошибка Лагранжа в точке 0.73: 1.1657341758564144e-15
# Абсолютная ошибка Ньютона в точке 0.73: 1.1102230246251565e-15
# ---
#
# Test: 21
# Абсолютная ошибка Лагранжа в точке 0.92: 3.3306690738754696e-16
# Абсолютная ошибка Ньютона в точке 0.92: 5.551115123125783e-16
# ---
# Абсолютная ошибка Лагранжа в точке 0.53: 1.9984014443252818e-15
# Абсолютная ошибка Ньютона в точке 0.53: 3.552713678800501e-15
# ---
# Абсолютная ошибка Лагранжа в точке 0.98: 6.661338147750939e-15
# Абсолютная ошибка Ньютона в точке 0.98: 5.88418203051333e-15
# ---
# Абсолютная ошибка Лагранжа в точке 0.77: 1.1102230246251565e-16
# Абсолютная ошибка Ньютона в точке 0.77: 3.3306690738754696e-16
# ---
#
# Test: 22
# Абсолютная ошибка Лагранжа в точке 0.37: 1.1102230246251565e-16
# Абсолютная ошибка Ньютона в точке 0.37: 1.1102230246251565e-16
# ---
# Абсолютная ошибка Лагранжа в точке 0.12: 1.4432899320127035e-15
# Абсолютная ошибка Ньютона в точке 0.12: 0.0
# ---
# Абсолютная ошибка Лагранжа в точке 0.58: 2.7755575615628914e-15
# Абсолютная ошибка Ньютона в точке 0.58: 4.440892098500626e-16
# ---
# Абсолютная ошибка Лагранжа в точке 0.33: 1.1102230246251565e-16
# Абсолютная ошибка Ньютона в точке 0.33: 0.0
# ---
#
# Test: 1
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Лагранжа в точке 0.52: inf
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Ньютона в точке 0.52: inf
# ---
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Лагранжа в точке 0.42: inf
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Ньютона в точке 0.42: inf
# ---
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Лагранжа в точке 0.87: inf
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Ньютона в точке 0.87: inf
# ---
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Лагранжа в точке 0.67: inf
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Ньютона в точке 0.67: inf
# ---
#
# Test: 2
# Абсолютная ошибка Лагранжа в точке 0.53: 9.304779169383437e-13
# Абсолютная ошибка Ньютона в точке 0.53: 2.552964367685817e-10
# ---
# Абсолютная ошибка Лагранжа в точке 0.52: 1.122824055954652e-12
# Абсолютная ошибка Ньютона в точке 0.52: 3.0278993201626747e-10
# ---
# Абсолютная ошибка Лагранжа в точке 0.97: 3.3306690738754696e-16
# Абсолютная ошибка Ньютона в точке 0.97: 1.33862920748129e-11
# ---
# Абсолютная ошибка Лагранжа в точке 0.73: 8.701372955499664e-15
# Абсолютная ошибка Ньютона в точке 0.73: 1.1513720532541072e-11
# ---
#
# Test: 3
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Лагранжа в точке 1.52: inf
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Ньютона в точке 1.52: inf
# ---
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Лагранжа в точке 1.52: inf
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Ньютона в точке 1.52: inf
# ---
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Лагранжа в точке 1.97: inf
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Ньютона в точке 1.97: inf
# ---
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Лагранжа в точке 1.77: inf
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Ньютона в точке 1.77: inf
# ---
#
# Test: 4
# Абсолютная ошибка Лагранжа в точке 0.13: 5.659807389242087e+191
# Абсолютная ошибка Ньютона в точке 0.13: 2.2306989072275043e+222
# ---
# Абсолютная ошибка Лагранжа в точке 0.12: 4.299843930293033e+191
# Абсолютная ошибка Ньютона в точке 0.12: 1.84010438875162e+222
# ---
# Абсолютная ошибка Лагранжа в точке 0.57: 2.1287179413424407e+191
# Абсолютная ошибка Ньютона в точке 0.57: 2.1268554717728984e+221
# ---
# Абсолютная ошибка Лагранжа в точке 0.33: 2.647889080667479e+192
# Абсолютная ошибка Ньютона в точке 0.33: 4.089915173086555e+222
# ---
#
# Test: 5
# Абсолютная ошибка Лагранжа в точке 1.07: 5.551115123125783e-16
# Абсолютная ошибка Ньютона в точке 1.07: 1.477162836494017e-11
# ---
# Абсолютная ошибка Лагранжа в точке 1.02: 0.0
# Абсолютная ошибка Ньютона в точке 1.02: 1.5501877559387367e-11
# ---
# Абсолютная ошибка Лагранжа в точке 1.47: 0.0
# Абсолютная ошибка Ньютона в точке 1.47: 1.9050525046360178e-11
# ---
# Абсолютная ошибка Лагранжа в точке 1.27: 1.942890293094024e-16
# Абсолютная ошибка Ньютона в точке 1.27: 1.6758788801141122e-11
# ---
#
# Test: 6
# Абсолютная ошибка Лагранжа в точке 0.92: 9.71445146547012e-17
# Абсолютная ошибка Ньютона в точке 0.92: 2.2169724216147824e-08
# ---
# Абсолютная ошибка Лагранжа в точке 0.62: 2.7200464103316335e-15
# Абсолютная ошибка Ньютона в точке 0.62: 6.552418330141307e-08
# ---
# Абсолютная ошибка Лагранжа в точке 1.07: 1.1102230246251565e-16
# Абсолютная ошибка Ньютона в точке 1.07: 2.1040173103781257e-08
# ---
# Абсолютная ошибка Лагранжа в точке 0.83: 1.3877787807814457e-16
# Абсолютная ошибка Ньютона в точке 0.83: 2.2858552550797384e-08
# ---
#
# Test: 7
# Абсолютная ошибка Лагранжа в точке 0.37: 1.6897594434794883e-13
# Абсолютная ошибка Ньютона в точке 0.37: 7.787881450838086e-12
# ---
# Абсолютная ошибка Лагранжа в точке 0.12: 8.659739592076221e-15
# Абсолютная ошибка Ньютона в точке 0.12: 4.509725926027386e-12
# ---
# Абсолютная ошибка Лагранжа в точке 0.57: 7.993605777301127e-15
# Абсолютная ошибка Ньютона в точке 0.57: 5.228595334472175e-13
# ---
# Абсолютная ошибка Лагранжа в точке 0.37: 1.6897594434794883e-13
# Абсолютная ошибка Ньютона в точке 0.37: 7.787881450838086e-12
# ---
#
# Test: 8
# Абсолютная ошибка Лагранжа в точке 0.77: 1.823208251039432e-12
# Абсолютная ошибка Ньютона в точке 0.77: 4.148414944893375e-11
# ---
# Абсолютная ошибка Лагранжа в точке 0.52: 1.4001844128586072e-09
# Абсолютная ошибка Ньютона в точке 0.52: 4.6450887580817835e-10
# ---
# Абсолютная ошибка Лагранжа в точке 0.97: 6.341593916658894e-13
# Абсолютная ошибка Ньютона в точке 0.97: 4.0388581368233645e-11
# ---
# Абсолютная ошибка Лагранжа в точке 0.73: 1.006617011967137e-11
# Абсолютная ошибка Ньютона в точке 0.73: 4.5489834121781314e-11
# ---
#
# Test: 9
# Абсолютная ошибка Лагранжа в точке 0.92: 5.102585021177219e-13
# Абсолютная ошибка Ньютона в точке 0.92: 5.5566662382489085e-12
# ---
# Абсолютная ошибка Лагранжа в точке 0.53: 3.685581173584751e-09
# Абсолютная ошибка Ньютона в точке 0.53: 3.5861612568410806e-09
# ---
# Абсолютная ошибка Лагранжа в точке 0.98: 3.023470362961689e-12
# Абсолютная ошибка Ньютона в точке 0.98: 2.131739229582763e-12
# ---
# Абсолютная ошибка Лагранжа в точке 0.77: 6.750336400962453e-12
# Абсолютная ошибка Ньютона в точке 0.77: 1.1744813455116798e-11
# ---
#
# Test: 10
# Абсолютная ошибка Лагранжа в точке 0.37: 6.540323838066797e-13
# Абсолютная ошибка Ньютона в точке 0.37: 3.772324008721739e-09
# ---
# Абсолютная ошибка Лагранжа в точке 0.12: 6.206146707654625e-14
# Абсолютная ошибка Ньютона в точке 0.12: 2.187294345645796e-09
# ---
# Абсолютная ошибка Лагранжа в точке 0.58: 7.743805596760467e-14
# Абсолютная ошибка Ньютона в точке 0.58: 2.0463075678378573e-10
# ---
# Абсолютная ошибка Лагранжа в точке 0.33: 9.333644968023691e-13
# Абсолютная ошибка Ньютона в точке 0.33: 4.861075431072948e-09
# ---
#
# Test: 11
# Абсолютная ошибка Лагранжа в точке 0.53: 1.871836019518014e-13
# Абсолютная ошибка Ньютона в точке 0.53: 7.062128659640621e-13
# ---
# Абсолютная ошибка Лагранжа в точке 0.43: 5.32018873400375e-13
# Абсолютная ошибка Ньютона в точке 0.43: 3.000044657142098e-12
# ---
# Абсолютная ошибка Лагранжа в точке 0.86: 5.551115123125783e-16
# Абсолютная ошибка Ньютона в точке 0.86: 4.9960036108132044e-14
# ---
# Абсолютная ошибка Лагранжа в точке 0.67: 1.3322676295501878e-15
# Абсолютная ошибка Ньютона в точке 0.67: 5.156985949383852e-14
# ---
#
# Test: 12
# Абсолютная ошибка Лагранжа в точке 0.64: 2.0958401680815086e-10
# Абсолютная ошибка Ньютона в точке 0.64: 2.0957846569302774e-10
# ---
# Абсолютная ошибка Лагранжа в точке 0.42: 1.350983058756583e-08
# Абсолютная ошибка Ньютона в точке 0.42: 1.3509157348323697e-08
# ---
# Абсолютная ошибка Лагранжа в точке 0.87: 2.98866487113969e-12
# Абсолютная ошибка Ньютона в точке 0.87: 2.9822810887480955e-12
# ---
# Абсолютная ошибка Лагранжа в точке 0.63: 3.196746201084011e-10
# Абсолютная ошибка Ньютона в точке 0.63: 3.196566900065534e-10
# ---
#
# Test: 13
# Абсолютная ошибка Лагранжа в точке 0.71: 0.0
# Абсолютная ошибка Ньютона в точке 0.71: 1.503241975342462e-13
# ---
# Абсолютная ошибка Лагранжа в точке 0.43: 3.0586644328423063e-13
# Абсолютная ошибка Ньютона в точке 0.43: 1.3944102816854098e-11
# ---
# Абсолютная ошибка Лагранжа в точке 0.87: 6.661338147750939e-16
# Абсолютная ошибка Ньютона в точке 0.87: 1.8030021919912542e-13
# ---
# Абсолютная ошибка Лагранжа в точке 0.67: 5.551115123125783e-16
# Абсолютная ошибка Ньютона в точке 0.67: 1.9040324872321435e-13
# ---
#
# Test: 14
# Абсолютная ошибка Лагранжа в точке 0.88: 3.1086244689504383e-15
# Абсолютная ошибка Ньютона в точке 0.88: 5.644595901799221e-11
# ---
# Абсолютная ошибка Лагранжа в точке 0.63: 2.886579864025407e-14
# Абсолютная ошибка Ньютона в точке 0.63: 1.3117551489472135e-10
# ---
# Абсолютная ошибка Лагранжа в точке 1.08: 3.9968028886505635e-15
# Абсолютная ошибка Ньютона в точке 1.08: 5.269695790843798e-11
# ---
# Абсолютная ошибка Лагранжа в точке 0.83: 3.9968028886505635e-15
# Абсолютная ошибка Ньютона в точке 0.83: 5.775069311653169e-11
# ---
#
# Test: 15
# Абсолютная ошибка Лагранжа в точке 0.44: 1.4414469617918257e-11
# Абсолютная ошибка Ньютона в точке 0.44: 1.6717577322467037e-09
# ---
# Абсолютная ошибка Лагранжа в точке 0.13: 5.838884931108623e-12
# Абсолютная ошибка Ньютона в точке 0.13: 2.2808998023648996e-09
# ---
# Абсолютная ошибка Лагранжа в точке 0.58: 1.7287282716438312e-12
# Абсолютная ошибка Ньютона в точке 0.58: 1.7476498026525178e-10
# ---
# Абсолютная ошибка Лагранжа в точке 0.37: 2.3366641954680745e-11
# Абсолютная ошибка Ньютона в точке 0.37: 3.2300394581241676e-09
# ---
#
# Test: 16
# Абсолютная ошибка Лагранжа в точке 0.73: 0.0
# Абсолютная ошибка Ньютона в точке 0.73: 4.453204471843719e-11
# ---
# Абсолютная ошибка Лагранжа в точке 0.52: 2.220446049250313e-16
# Абсолютная ошибка Ньютона в точке 0.52: 1.1764125541768866e-09
# ---
# Абсолютная ошибка Лагранжа в точке 0.97: 6.661338147750939e-16
# Абсолютная ошибка Ньютона в точке 0.97: 5.157896332264045e-11
# ---
# Абсолютная ошибка Лагранжа в точке 0.73: 0.0
# Абсолютная ошибка Ньютона в точке 0.73: 4.453204471843719e-11
# ---
#
# Test: 17
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Лагранжа в точке 0.84: inf
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Ньютона в точке 0.84: inf
# ---
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Лагранжа в точке 0.62: inf
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Ньютона в точке 0.62: inf
# ---
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Лагранжа в точке 1.07: inf
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Ньютона в точке 1.07: inf
# ---
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Лагранжа в точке 0.83: inf
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Ньютона в точке 0.83: inf
# ---
#
# Test: 18
# Абсолютная ошибка Лагранжа в точке 0.37: 5.115463608262871e-12
# Абсолютная ошибка Ньютона в точке 0.37: 2.0530799282880707e-13
# ---
# Абсолютная ошибка Лагранжа в точке 0.12: 1.039279773351609e-12
# Абсолютная ошибка Ньютона в точке 0.12: 1.781325087435448e-12
# ---
# Абсолютная ошибка Лагранжа в точке 0.58: 3.6126657221302594e-13
# Абсолютная ошибка Ньютона в точке 0.58: 8.24618151540335e-14
# ---
# Абсолютная ошибка Лагранжа в точке 0.33: 5.997702334781252e-12
# Абсолютная ошибка Ньютона в точке 0.33: 3.4190011932722086e-13
# ---
#
# Test: 19
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Лагранжа в точке 0.53: inf
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Ньютона в точке 0.53: inf
# ---
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Лагранжа в точке 0.43: inf
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Ньютона в точке 0.43: inf
# ---
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Лагранжа в точке 0.86: inf
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Ньютона в точке 0.86: inf
# ---
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Лагранжа в точке 0.67: inf
# Невозможно вычислить значение функции в узле `0`. Ошибка: math domain error
# Абсолютная ошибка Ньютона в точке 0.67: inf
# ---
#
# Test: 20
# Абсолютная ошибка Лагранжа в точке 0.77: 8.493206138382448e-15
# Абсолютная ошибка Ньютона в точке 0.77: 3.9530899942352704e-08
# ---
# Абсолютная ошибка Лагранжа в точке 0.52: 5.497213795280231e-12
# Абсолютная ошибка Ньютона в точке 0.52: 9.307206720321481e-07
# ---
# Абсолютная ошибка Лагранжа в точке 0.97: 2.6645352591003757e-15
# Абсолютная ошибка Ньютона в точке 0.97: 4.081893867358133e-08
# ---
# Абсолютная ошибка Лагранжа в точке 0.73: 4.4797499043625066e-14
# Абсолютная ошибка Ньютона в точке 0.73: 3.522671621070117e-08
# ---
#
# Test: 21
# Абсолютная ошибка Лагранжа в точке 0.92: 3.3306690738754696e-16
# Абсолютная ошибка Ньютона в точке 0.92: 2.1544321882061013e-11
# ---
# Абсолютная ошибка Лагранжа в точке 0.53: 1.6775469902086115e-13
# Абсолютная ошибка Ньютона в точке 0.53: 4.200475522964098e-10
# ---
# Абсолютная ошибка Лагранжа в точке 0.98: 4.440892098500626e-16
# Абсолютная ошибка Ньютона в точке 0.98: 2.175248869917823e-11
# ---
# Абсолютная ошибка Лагранжа в точке 0.77: 2.220446049250313e-16
# Абсолютная ошибка Ньютона в точке 0.77: 2.107380936422487e-11
# ---
#
# Test: 22
# Абсолютная ошибка Лагранжа в точке 0.37: 2.7200464103316335e-13
# Абсолютная ошибка Ньютона в точке 0.37: 1.6138201885951275e-12
# ---
# Абсолютная ошибка Лагранжа в точке 0.12: 6.572520305780927e-14
# Абсолютная ошибка Ньютона в точке 0.12: 9.419132140919828e-13
# ---
# Абсолютная ошибка Лагранжа в точке 0.58: 2.2870594307278225e-14
# Абсолютная ошибка Ньютона в точке 0.58: 8.693046282814976e-14
# ---
# Абсолютная ошибка Лагранжа в точке 0.33: 4.773959005888173e-14
# Абсолютная ошибка Ньютона в точке 0.33: 2.082223282684481e-12
# ---
#
#       x  Степень полинома  Нижняя граница  Ошибка интерполяции Лагранжа  Ошибка интерполяции Ньютона  Верхняя граница
# 0  0.13                 1   -3.355370e-04                 -3.322684e-04                -3.322684e-04    -3.295799e-04
# 1  0.12                 1   -3.684328e-04                 -3.653239e-04                -3.653239e-04    -3.618917e-04
# 2  0.57                 1   -2.618213e-04                 -2.576728e-04                -2.576728e-04    -2.524362e-04
# 3  0.33                 1   -7.611728e-05                 -7.546078e-05                -7.546078e-05    -7.423800e-05
# 4  0.13                 2   -2.848322e-06                 -2.711549e-06                -2.711549e-06    -2.600805e-06
# 5  0.12                 2   -3.641051e-06                 -3.457583e-06                -3.457583e-06    -3.324646e-06
# 6  0.57                 2    3.915378e-06                  4.113761e-06                 4.113761e-06     4.288003e-06
# 7  0.33                 2    6.201943e-07                  6.495453e-07                 6.495453e-07     6.792178e-07
